# %%
# %run ../../functions.ipynb

# %%
fluorometry_measurement_standard = {"date" : "7/05/18",
"standard name" : "Lambda DNA",
"concentration": [32000, 16000, 8000, 4000, 2000, 1000, 500, 250, 25, 2.5, 0.25, 0.025, 0.00],                                  
"fluorescence [RFU]" : [448.15, 186.65, 103.92, 95.257, 88.229, 81.404, 80.163, 77.141, 87.672, 90.449, 85.529, 86.477, 86.5135],
"concentration units" : "[ng/ml]",
"Excitation" : "351 nm", 
"Emission"  : "454 nm",
"fluorochrome" : "Hoechst 33258",
"blank" : [86.857, 89.219, 89.156, 80.822]                                    
}

blank = [86.857, 89.219, 89.156, 80.822]

plot_with_more_data(fluorometry_measurement_standard["concentration"],
                   fluorometry_measurement_standard["fluorescence [RFU]"],
                   fluorometry_measurement_standard["date"],
                   fluorometry_measurement_standard["Excitation"],
                   fluorometry_measurement_standard["Emission"],
                   fluorometry_measurement_standard["fluorochrome"])


lod([86.857, 89.219, 89.156, 80.822])
# Out:
# blank standard deviation: 3.4210269291544595
# blank average: 86.5135
# detection limit: 96.77658078746337
# (3.4210269291544595, 86.5135, 96.77658078746337)

# %%
lod([86.857, 89.219, 89.156, 80.822])
# Out:
# blank standard deviation: 3.4210269291544595
# blank average: 86.5135
# detection limit: 96.77658078746337
# (3.4210269291544595, 86.5135, 96.77658078746337)

# %%
fluorometry_measurement_standard_minus_9_points = {"date" : "7/05/18",
"standard name" : "Lambda DNA",
"concentration": [32000, 16000, 8000],                                  
"fluorescence [RFU]" : [448.15, 186.65, 103.92],
"concentration units" : "[ng/ml]",
"Excitation" : "500 nm", 
"Emission"  : "530 nm",
"fluorochrome" : "Hoechst 33258",
"blank" : [86.857, 89.219, 89.156, 80.822]                                    
}

blank = [86.857, 89.219, 89.156, 80.822]

plot_with_more_data(fluorometry_measurement_standard_minus_9_points["concentration"],
                   fluorometry_measurement_standard_minus_9_points["fluorescence [RFU]"],
                   fluorometry_measurement_standard_minus_9_points["date"],
                   fluorometry_measurement_standard_minus_9_points["Excitation"],
                   fluorometry_measurement_standard_minus_9_points["Emission"],
                   fluorometry_measurement_standard_minus_9_points["fluorochrome"])


lod([86.857, 89.219, 89.156, 80.822])
# Out:
# blank standard deviation: 3.4210269291544595
# blank average: 86.5135
# detection limit: 96.77658078746337
# (3.4210269291544595, 86.5135, 96.77658078746337)

# %%
hoechst_33258_detection_range = [[8000, 32000], "can be upper"]
