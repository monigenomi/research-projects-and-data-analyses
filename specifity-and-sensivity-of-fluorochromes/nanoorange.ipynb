# %%
#NanoOrange this experiment evidently doesn't work!!
#maybe because of the mystake with volumes that I used
# %run ../../functions.ipynb
fluorometry_measurement_standard = {"date" : "10/05/18",
"standard name" : "BSA",
"concentration": [528000, 264000, 128000, 64000, 32000, 16000, 5538.8, 2769.4,
                 1384.7, 692.36, 346.18, 173.09, 17.3, 1.73, 0.173, 0.00],                                  
"fluorescence [RFU]" : [3.278, 3.812, 4.128, 3.378, 3.778,3.626, 3.277, 3.583,
                       2.562, 2.596, 2.394, 2.629, 2.635, 2.285, 1.934, 2.2845],
"concentration units" : "[ng/ml]",
"Excitation" : "470", 
"Emission"  : "570",
"fluorochrome" : "NanoOrange",
"blank" : [2.471, 2.404, 2.078, 2.185]                                    
}

blank = [2.471, 2.404, 2.078, 2.185]

plot_with_more_data(fluorometry_measurement_standard["concentration"],
                   fluorometry_measurement_standard["fluorescence [RFU]"],
                   fluorometry_measurement_standard["date"],
                   fluorometry_measurement_standard["Excitation"],
                   fluorometry_measurement_standard["Emission"],
                   fluorometry_measurement_standard["fluorochrome"])


lod(blank)
blank = [2.471, 2.404, 2.078, 2.185]


pd.DataFrame(fluorometry_measurement_standard)
# Out:
# blank standard deviation: 0.15937769605562763
# blank average: 2.2845
# detection limit: 2.762633088166883
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-efc3e441d61c> in <module>()
#      29
#      30
# ---> 31 pd.DataFrame(fluorometry_measurement_standard)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
#     332             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     459             arrays = [data[k] for k in keys]
#     460
# ...

# %%
fluorometry_measurement_standard_2 = {"date" : "10/05/18",
"standard name" : "BSA",
"concentration": [32000, 16000, 5538.8, 2769.4],                                  
"fluorescence [RFU]" : [3.778,3.626, 3.277, 3.583
                       ],
"concentration units" : "[ng/ml]",
"Excitation" : "470", 
"Emission"  : "570",
"fluorochrome" : "NanoOrange",
"blank" : [2.471, 2.404, 2.078, 2.185]                                    
}

plot_with_more_data(fluorometry_measurement_standard_2["concentration"],
                   fluorometry_measurement_standard_2["fluorescence [RFU]"],
                   fluorometry_measurement_standard_2["date"],
                   fluorometry_measurement_standard_2["Excitation"],
                   fluorometry_measurement_standard_2["Emission"],
                   fluorometry_measurement_standard_2["fluorochrome"])

# %%
fluorometry_measurement_standard = {"date" : "10/05/18",
"standard name" : "BSA",
"concentration": [528000, 264000, 128000, 64000, 32000, 16000, 5538.8, 2769.4,
                 1384.7, 692.36, 346.18, 173.09, 17.3, 1.73, 0.173, 0.00],                                  
"fluorescence [RFU]" : [3.278, 3.812, 4.128, 3.378, 3.778,3.626, 3.277, 3.583,
                       2.562, 2.596, 2.394, 2.629, 2.635, 2.285, 1.934, 2.2845],
"concentration units" : "[ng/ml]",
"Excitation" : "470", 
"Emission"  : "570",
"fluorochrome" : "NanoOrange",
"blank" : [2.471, 2.404, 2.078, 2.185]                                    
}

blank = [2.471, 2.404, 2.078, 2.185]

plot_with_more_data(fluorometry_measurement_standard["concentration"],
                   fluorometry_measurement_standard["fluorescence [RFU]"],
                   fluorometry_measurement_standard["date"],
                   fluorometry_measurement_standard["Excitation"],
                   fluorometry_measurement_standard["Emission"],
                   fluorometry_measurement_standard["fluorochrome"])


lod(blank)
blank = [2.471, 2.404, 2.078, 2.185]
# Out:
# blank standard deviation: 0.15937769605562763
# blank average: 2.2845
# detection limit: 2.762633088166883

# %%
fluorometry_measurement_standard_3 = {"date" : "11/05/18",
"standard name" : "BSA",
"concentration": [128000, 64000, 32000, 16000, 5538.8, 2769.4,
                 1384.7, 692.36, 17.3, 1.73, 0.173, 0.00],                                  
"fluorescence [RFU]" : [2.911, 3.139, 3.049, 3.177,
                        3.553, 3.142, 3.299, 2.778,
                        2.796, 2.918, 3.215, 2.999333333333334 ],
"concentration units" : "[ng/ml]",
"Excitation" : "470", 
"Emission"  : "570",
"fluorochrome" : "NanoOrange",
"blank" : [2.801, 2.968, 3.229]                                    
}

blank = [2.801, 2.968, 3.229]

plot_with_more_data(fluorometry_measurement_standard_3["concentration"],
                   fluorometry_measurement_standard_3["fluorescence [RFU]"],
                   fluorometry_measurement_standard_3["date"],
                   fluorometry_measurement_standard_3["Excitation"],
                   fluorometry_measurement_standard_3["Emission"],
                   fluorometry_measurement_standard_3["fluorochrome"])


lod(blank)
blank = [2.471, 2.404, 2.078, 2.185]
# Out:
# blank standard deviation: 0.17612937164356077
# blank average: 2.999333333333334
# detection limit: 3.5277214482640162

# %%
fluorometry_measurement_standard_4 = {"date" : "11/05/18",
"standard name" : "BSA",
"concentration": [16000, 5538.8, 2769.4,
                 1384.7, 692.36, 17.3, 1.73, 0.173, 0.00],                                  
"fluorescence [RFU]" : [3.177,
                        3.553, 3.142, 3.299, 2.778,
                        2.796, 2.918, 3.215, 2.999333333333334 ],
"concentration units" : "[ng/ml]",
"Excitation" : "470", 
"Emission"  : "570",
"fluorochrome" : "NanoOrange",
"blank" : [2.801, 2.968, 3.229]                                    
}

blank = [2.801, 2.968, 3.229]

plot_with_more_data(fluorometry_measurement_standard_4["concentration"],
                   fluorometry_measurement_standard_4["fluorescence [RFU]"],
                   fluorometry_measurement_standard_4["date"],
                   fluorometry_measurement_standard_4["Excitation"],
                   fluorometry_measurement_standard_4["Emission"],
                   fluorometry_measurement_standard_4["fluorochrome"])
_4
_4
lod(blank)
blank = [2.471, 2.404, 2.078, 2.185]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-7ce8adfcc0ad> in <module>()
#      21                    fluorometry_measurement_standard_4["Emission"],
#      22                    fluorometry_measurement_standard_4["fluorochrome"])
# ---> 23 _4
#      24 _4
#      25 lod(blank)
#
# NameError: name '_4' is not defined

# %%
blank = [2.801, 2.968, 3.229]
lod(blank)
# Out:
# blank standard deviation: 0.17612937164356077
# blank average: 2.999333333333334
# detection limit: 3.5277214482640162
# (0.17612937164356077, 2.999333333333334, 3.5277214482640162)
