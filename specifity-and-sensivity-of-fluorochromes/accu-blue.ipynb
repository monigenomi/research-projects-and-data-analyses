# %%
# %run ../../functions.ipynb

# %%
fluorometry_measurement_standard = {"date" : "7/05/18",
"standard name" : "Lambda DNA",
"concentration": [32000, 16000, 8000, 4000,
                  2000, 1000, 500, 250,
                  25, 2.5, 0.25, 0.025,
                  0.00],                                  
"fluorescence [RFU]" : [1158.6, 1034.3, 861.61, 639.02,
                        582.45, 618.61, 590.73, 700.22,
                        521.19, 650.60, 601.44, 562.65,
                        608.6600000000001],
"concentration units" : "[ng/ml]",
"Excitation" : "509 nm", 
"Emission"  : "530 nm",
"fluorochrome" : "AccuBlue",
"blank" : [564.82, 652.50]                                    
}

plot_with_more_data(fluorometry_measurement_standard["concentration"],
                   fluorometry_measurement_standard["fluorescence [RFU]"],
                   fluorometry_measurement_standard["date"],
                   fluorometry_measurement_standard["Excitation"],
                   fluorometry_measurement_standard["Emission"],
                   fluorometry_measurement_standard["fluorochrome"])


lod(fluorometry_measurement_standard["blank"])
# Out:
# blank standard deviation: 43.839999999999975
# blank average: 608.6600000000001
# detection limit: 740.1800000000001
# (43.839999999999975, 608.6600000000001, 740.1800000000001)

# %%
fluorometry_measurement_standard
# Out:
# {'Emission': '530 nm',
#  'Excitation': '509 nm',
#  'blank': [564.82, 652.5],
#  'concentration': [32000,
#   16000,
#   8000,
#   4000,
#   2000,
#   1000,
#   500,
#   250,
#   25,
#   2.5,
#   0.25,
#   0.025,
#   0.0],
#  'concentration units': '[ng/ml]',
#  'date': '7/05/18',
#  'fluorescence [RFU]': [1158.6,
#   1034.3,
#   861.61,
#   639.02,
#   582.45,
#   618.61,
#   590.73,
#   700.22,
#   521.19,
#   650.6,
#   601.44,
#   562.65,
#   608.6600000000001],
#  'fluorochrome': 'AccuBlue',
#  'standard name': 'Lambda DNA'}

# %%
lod([564.82, 652.50])
# Out:
# blank standard deviation: 43.839999999999975
# blank average: 608.6600000000001
# detection limit: 740.1800000000001
# (43.839999999999975, 608.6600000000001, 740.1800000000001)

# %%
fluorometry_measurement_standard_minus_ten_points = {"date" : "7/05/18",
"standard name" : "Lambda DNA",
"concentration": [32000, 16000, 8000],                                  
"fluorescence [RFU]" : [1158.6, 1034.3, 861.61],
"concentration units" : "[ng/ml]",
"Excitation" : "509 nm", 
"Emission"  : "530 nm",
"fluorochrome" : "AccuBlue",
"blank" : [564.82, 652.50]                                    
}

plot_with_more_data(fluorometry_measurement_standard_minus_ten_points["concentration"],
                   fluorometry_measurement_standard_minus_ten_points["fluorescence [RFU]"],
                   fluorometry_measurement_standard_minus_ten_points["date"],
                   fluorometry_measurement_standard_minus_ten_points["Excitation"],
                   fluorometry_measurement_standard_minus_ten_points["Emission"],
                   fluorometry_measurement_standard_minus_ten_points["fluorochrome"])

# %%
AccuBlue_detecton_range = [8000, 32000]
