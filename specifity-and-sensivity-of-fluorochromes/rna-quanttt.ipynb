# %%
# %run ../../functions.ipynb

# %%
fluorometry_measurement_standard = {"date" : "7/05/18",
"standard name" : "TRIZOL RNA from mouse brain",
"concentration": [128000, 64000, 32000, 16000,
                  8000, 4000,2000, 1000,
                  500, 250,  2.5,
                  0.025, 0.00],  
                                    
"fluorescence [RFU]" : [10.794, 12.641, 13.596, 9.545,
                       5.955, 3.411, 3.423, 1.640,
                       1.183, 1.044, 1.347,
                       1.479, 0.8196666666666667],
"concentration units" : "[ng/ml]",
"Excitation" : "644 nm", 
"Emission"  : "673 nm",
"fluorochrome" : "RNA Assay Kit Quant - TT",
"blank" : [1.327, 0.455, 0.677]                                    
}

blank = [1.327, 0.455, 0.677]

plot_with_more_data(fluorometry_measurement_standard["concentration"],
                   fluorometry_measurement_standard["fluorescence [RFU]"],
                   fluorometry_measurement_standard["date"],
                   fluorometry_measurement_standard["Excitation"],
                   fluorometry_measurement_standard["Emission"],
                   fluorometry_measurement_standard["fluorochrome"])

# %%
lod(blank)

fluorometry_measurement_standard_2 = {"date" : "7/05/18",
"standard name" : "TRIZOL RNA from mouse brain",
"concentration": [32000, 16000,
                  8000, 4000,2000],  
                                    
"fluorescence [RFU]" : [13.596, 9.545,
                       5.955, 3.411, 3.423],
"concentration units" : "[ng/ml]",
"Excitation" : "644 nm", 
"Emission"  : "673 nm",
"fluorochrome" : "RNA Assay Kit Quant - TT",
"blank" : [1.327, 0.455, 0.677]                                    
}

plot_with_more_data(fluorometry_measurement_standard_2["concentration"],
                   fluorometry_measurement_standard_2["fluorescence [RFU]"],
                   fluorometry_measurement_standard_2["date"],
                   fluorometry_measurement_standard_2["Excitation"],
                   fluorometry_measurement_standard_2["Emission"],
                   fluorometry_measurement_standard_2["fluorochrome"])
# Out:
# blank standard deviation: 0.3700102100693379
# blank average: 0.8196666666666667
# detection limit: 1.9296972968746804
